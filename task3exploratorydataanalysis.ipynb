# %% [markdown]
# # Varsha Daulat Pathare
# ## The Spark Foundation
# #### GRIP_ jan21
# Data Science & Business Analytics Intern
#
# Task 3:Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Reading the Dataset

# %%
df=pd.read_csv("C:\\Users\\varsha pathare\\Downloads\\SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
# checking data type
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
#check the rows and column
df.shape
# Out:
# (9994, 13)

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# univariate Analysis

# %%
#Analysis Segment of people buying from the supermart.
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df['Segment'].value_counts()/len(df['Segment'])*100
# Out:
# Consumer       51.941165
# Corporate      30.218131
# Home Office    17.840704
# Name: Segment, dtype: float64

# %%
S=(df['Segment'].value_counts()/len(df['Segment'])*100).plot(kind='bar',color='g')

# %% [markdown]
# Follwing Conclusions can be made From the graph:
#     1)50% of people belongs to consumer Class
#     2)20-30% of the people belongs to corporate And Home offices

# %%
#Anaysing ship mode for the Supermart
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
M=(df['Ship Mode'].value_counts()/len(df['Ship Mode'])*100)
M
# Out:
# Standard Class    59.715829
# Second Class      19.461677
# First Class       15.389234
# Same Day           5.433260
# Name: Ship Mode, dtype: float64

# %%
M.plot(kind='bar',color='red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Following Conclusion can be made from the graph
# most of the deliveries belong to the standard class(Around 60%)
# very less %of deliveries were made on the dame day

# %%
# Analying catagory of items in the supermart
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
H=(df['Category'].value_counts()/len(df['Category'])*100)
H.plot(kind='bar',color='pink')
# Out:
# <AxesSubplot:>

# %%
#profit and sales per Category
df.groupby('Category')['Profit','Sales'].agg(['sum']).plot.bar(rot=45,figsize=(15,12),color={'blue','red'},width=0.3)
plt.legend(loc=1,fontsize='x-large',labelspacing=1.8)
plt.title('Total Profit and Sales per Category',fontsize=20)
plt.show()

# %%
#profit and sales per sub-Category
df.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar(rot=45,figsize=(15,12),color={'blue','purple'},width=0.3)
plt.legend(loc=1,fontsize='x-large',labelspacing=1.8)
plt.title('Total Profit and Sales per Sub-Category',fontsize=20)
plt.show()

# %%
#region-wise count of categorical sales
sns.set(rc={'figure.figsize':(20,10)})
sns.countplot(x="Category",hue="Region",data=df,palette='plasma')
plt.xticks(rotation=4)
plt.legend(loc=2,fontsize='x-large',labelspacing=1.8)
plt.title('Region-Wise count of Categorial sales',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Region-Wise count of Categorial sales')

# %%
#region-wise count of categorical sales
sns.set(rc={'figure.figsize':(24,18)})
sns.countplot(x="Sub-Category",hue="Region",data=df,palette='rainbow',linewidth=0.1)
plt.xticks(rotation=45,fontsize=16)
plt.xlabel("Subcategory",fontsize=18)
plt.yticks(fontsize=16)
plt.ylabel("Count",fontsize=18)
plt.legend(loc=2,fontsize='x-large',labelspacing=1.8)
plt.title('Region-Wise count of SubCategorial sales',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Region-Wise count of SubCategorial sales')

# %%
#profit and sales per sub-Category
df.groupby('State')['Profit','Sales'].agg(['sum']).plot.bar(rot=45,figsize=(15,12),color={'blue','purple'},width=0.3)
plt.legend(loc=1,fontsize='x-large',labelspacing=2.0)
plt.title('Total Profit and Sales per state',fontsize=20)
plt.show()

# %%
#Total cost and profit percentage  will help to understand the data better.
df['Cost']=df['Sales']-df['Profit']
df['Profit %']=(df['Profit']/df['Cost'])*100
df
# Out:
#            Ship Mode      Segment        Country             City  \
# 0       Second Class     Consumer  United States        Henderson
# 1       Second Class     Consumer  United States        Henderson
# 2       Second Class    Corporate  United States      Los Angeles
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 4     Standard Class     Consumer  United States  Fort Lauderdale
# 5     Standard Class     Consumer  United States      Los Angeles
# 6     Standard Class     Consumer  United States      Los Angeles
# 7     Standard Class     Consumer  United States      Los Angeles
# 9980    85.9800         1      0.00    22.3548    63.6252  35.135135
# 9981    16.5200         5      0.20     5.3690    11.1510  48.148148
# 9982    35.5600         7      0.00    16.7132    18.8468  88.679245
# 9983    97.9800         2      0.00    27.4344    70.5456  38.888889
# 9984    31.5000        10      0.00    15.1200    16.3800  92.307692
# 9985    55.6000         4      0.00    16.1240    39.4760  40.845070
# 9986    36.2400         1      0.00    15.2208    21.0192  72.413793
# 9987    79.9900         1      0.00    28.7964    51.1936  56.250000
# 9988   206.1000         5      0.00    55.6470   150.4530  36.986301
# 9989    25.2480         3      0.20     4.1028    21.1452  19.402985
# 9990    91.9600         2      0.00    15.6332    76.3268  20.481928
# 9991   258.5760         2      0.20    19.3932   239.1828   8.108108
# 9992    29.6000         4      0.00    13.3200    16.2800  81.818182
# 9993   243.1600         2      0.00    72.9480   170.2120  42.857143
#
# [9994 rows x 15 columns]

# %%
#Creating a correlation heatmap
fig=plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),cmap='nipy_spectral',annot=True,linecolor='red',linewidth=1.5)
b,t=plt.ylim()
b+=0.5
t-=0.5
plt.ylim(b,t)
# Out:
# (7.5, -0.5)

# %%
#plot count of ship modes region wise
plt.figure(figsize=(15,11))
sns.countplot(x="Ship Mode",hue="Region",data=df,palette='afmhot')
plt.xticks(rotation=45)
plt.title('Regionwise counts of shipmoddes',fontsize=20)
plt.show()

# %% [markdown]
# # An insight into accquired profit

# %%
#state wise plot for sales
plt.figure(figsize=[20,20])
df['State'].value_counts().plot.barh(color='orange')
plt.title("Statewise Sales",fontsize=30,backgroundcolor='cyan')
# Out:
# Text(0.5, 1.0, 'Statewise Sales')

# %%
#city wise performance
df['City'].value_counts()
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
# Houston            377
# Chicago            314
# Columbus           222
# San Diego          170
# Springfield        163
# Dallas             157
# Jacksonville       125
# Detroit            115
# Newark              95
# Richmond            90
# Jackson             82
# Columbia            81
# Aurora              68
# Phoenix             63
# Long Beach          61
# Arlington           60
# San Antonio         59
# Louisville          57
# Miami               57
# Rochester           53
# Charlotte           52
# Henderson           51
# Lakewood            49
# Lancaster           46
# Milwaukee           45
#                   ...
# Conway               1
# Kissimmee            1
# Palatine             1
# Davis                1
# La Quinta            1
# Layton               1
# Normal               1
# Linden               1
# Waukesha             1
# Cedar Rapids         1
# Champaign            1
# Melbourne            1
# Rochester Hills      1
# Vacaville            1
# Tinley Park          1
# Santa Maria          1
# Billings             1
# Rogers               1
# Goldsboro            1
# Margate              1
# Atlantic City        1
# Montebello           1
# Rock Hill            1
# Redding              1
# Missouri City        1
# Holyoke              1
# Hagerstown           1
# Whittier             1
# Abilene              1
# Citrus Heights       1
# Name: City, Length: 531, dtype: int64

# %% [markdown]
# # thanks
